# %% [markdown]
# Coding Assignment: Data Exploration and Visualization Using Pandas
#
# Dataset 01:
#
# Use the Iris Species dataset from Kaggle, which contains measurements of different species of iris flowers.

# %% [markdown]
# Instructions:
#
# 1.Importing the Dataset:
#
# Load the dataset into a pandas DataFrame.
#
# Display the first 5 rows of the dataset.

# %%
import pandas as pd

# Load the dataset
my_data = pd.read_csv("Iris.csv")

# Display the first 5 rows
my_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# We import the dataset using pandas and store it in a DataFrame. The head() function is then used to display the first five rows so that we can see what the data looks like.

# %% [markdown]
# 2.Basic Data Exploration:
#
# .Data Summary:
#
# Display basic information about the dataset, including the number of rows and columns, data types of each column, and memory usage.
#
# Generate descriptive statistics for the numerical columns (e.g., mean, median, standard deviation).
#
# .Check for Missing Values:
#
# Identify any missing values in the dataset and explain how you would handle them if there were any.
#
# .Value Counts:
#
# Display the count of each unique species in the species column.

# %%
my_data.shape
# Out:
# (150, 6)

# %%
# Basic information about the dataset
my_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
# Descriptive statistics
my_data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Median of numerical columns
my_data.median(numeric_only=True)
# Out:
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
# Count missing values in each column
my_data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Fill missing numerical values with the median
#my_data.fillna(my_data.median(numeric_only=True), inplace=True)

# %%
# Count each unique species
my_data["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# We explore the dataset to understand its structure and contents. We check the number of rows and columns, data types, memory usage, numerical statistics, and missing values. We also use value_counts() to see how many records belong to each species.

# %% [markdown]
# 3.Filtering and Sorting:
#
# Filter the dataset to show only the rows where the sepal_length is greater than 5.0.
#
# Sort the filtered dataset by petal_length in descending order.

# %%
# Filter rows where sepal length is greater than 5.0
my_filtered_data = my_data[my_data["SepalLengthCm"] > 5.0]

# %%
my_filtered_data = my_filtered_data.sort_values(by="PetalLengthCm", ascending=False)

# %%
my_filtered_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 122  123            7.7           2.8            6.7           2.0
# 105  106            7.6           3.0            6.6           2.1
# 131  132            7.9           3.8            6.4           2.0
# ..   ...            ...           ...            ...           ...
# 28    29            5.2           3.4            1.4           0.2
# 33    34            5.5           4.2            1.4           0.2
# 16    17            5.4           3.9            1.3           0.4
# 36    37            5.5           3.5            1.3           0.2
# 14    15            5.8           4.0            1.2           0.2
#
#             Species
# 118  Iris-virginica
# 117  Iris-virginica
# 122  Iris-virginica
# 105  Iris-virginica
# 131  Iris-virginica
# ..              ...
# ...

# %% [markdown]
# We filter the dataset to select only the flowers whose SepalLengthCm is greater than 5.0. Then, we sort the filtered data by PetalLengthCm from highest to lowest to make the data easier to analyze.

# %%
# Create a new column for the sepal-to-petal ratio
my_data["sepal_petal_ratio"] = my_data["SepalLengthCm"] / my_data["PetalLengthCm"]

# %%
# Display the dataset
my_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  sepal_petal_ratio
# 0       Iris-setosa           3.642857
# 1       Iris-setosa           3.500000
# 2       Iris-setosa           3.615385
# ...

# %% [markdown]
# We create a new column called sepal_petal_ratio by dividing the sepal length by the petal length. This ratio helps us compare the lengths of the sepal and petal for each flower.

# %% [markdown]
# 6.Data Visualization:
#
# Histogram:
#
# Create a histogram to visualize the distribution of sepal_length values.
#
# Scatter Plot:
#
# Create a scatter plot with sepal_length on the x-axis and petal_length on the y-axis. Use different colors to represent different species.
#
# Box Plot:
#
# Create a box plot for the sepal_width values, grouped by species.

# %%
import matplotlib.pyplot as plt

plt.hist(my_data["SepalLengthCm"])
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.title("Distribution of Sepal Length")
plt.show()

# %% [markdown]
# The histogram shows how the sepal length values are distributed in the dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(
    data=my_data,
    x="SepalLengthCm",
    y="PetalLengthCm",
    hue="Species"
)

plt.title("SepalLengthCm vs PetalLengthCm")
plt.show()

# %% [markdown]
# The scatter plot shows the relationship between sepal length and petal length. Different colors are used to identify different species.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    data=my_data,
    x="Species",
    y="SepalWidthCm"
)

plt.title("Sepal Width by Species")
plt.show()

# %% [markdown]
# The box plot compares the sepal width of different species and helps us see their spread, median, and possible outliers.

# %% [markdown]
# 7.Correlation Matrix
#
# Calculate the correlation matrix for the numerical features and create a heatmap to visualize the correlations using seaborn.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
correlation_matrix = my_data.corr(numeric_only=True)

# Display the correlation matrix
print(correlation_matrix)

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")

plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
#                          Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id                 1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm      0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm      -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm      0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm       0.899759       0.817954     -0.356544       0.962757
# sepal_petal_ratio -0.828586      -0.698962      0.588486      -0.934778
#
#                    PetalWidthCm  sepal_petal_ratio
# Id                     0.899759          -0.828586
# SepalLengthCm          0.817954          -0.698962
# SepalWidthCm          -0.356544           0.588486
# PetalLengthCm          0.962757          -0.934778
# PetalWidthCm           1.000000          -0.896479
# sepal_petal_ratio     -0.896479           1.000000

# %% [markdown]
# We calculate the correlation between numerical features to understand how they are related to each other. A heatmap is used to display these correlations visually, making strong and weak relationships easier to identify.
