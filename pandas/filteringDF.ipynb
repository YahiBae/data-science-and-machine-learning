# %%
import pandas as pd

# %%
titanic_df = pd.read_csv("titanic.datatype")
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# conditional based filtering

# %%
mask = titanic_df.Fare > 100

# %%
fare_100 = titanic_df[mask]

# %%
fare_100
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
fare_100.count()
# Out:
# PassengerId    53
# Survived       53
# Pclass         53
# Name           53
# Sex            53
# Age            48
# SibSp          53
# Parch          53
# Ticket         53
# Fare           53
# Cabin          43
# Embarked       53
# dtype: int64

# %%
fare_100.shape
# Out:
# (53, 12)

# %% [markdown]
# out of 891 passangers, only 53 passangers paid more than 100 $ in fare.

# %%
female_fare_100 = fare_100[fare_100["Sex"] == "female"]

# %%
female_fare_100.shape
# Out:
# (34, 12)

# %%
print(f"out of 53, {round((34/53 * 100), 2)}% are female passengers")
# Out:
# out of 53, 64.15% are female passengers

# %%
fare_100_male = titanic_df[
    (titanic_df["Fare"] > 100) & (titanic_df["Sex"] == "male")
]

# %%
fare_100_male.shape
# Out:
# (19, 12)

# %%
# what is survival rate of higher-class passengers?
high_class_survival = titanic_df[
    (titanic_df.Pclass== 1) & (titanic_df.Survived == 1)
]

# %%
high_class_survival.shape
# Out:
# (136, 12)

# %%
136/216 * 100
# Out:
# 62.96296296296296

# %% [markdown]
# filtering using existing methods

# %%
null_cabin = titanic_df[titanic_df["Cabin"].isna()]#isna()

# %%
null_cabin.head()
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %%
null_cabin.shape
# Out:
# (687, 12)

# %%
titanic_df.Cabin.isna().sum()#total null values in cabin column
# Out:
# np.int64(687)

# %%
#duplicate data
duplicate_ticket = titanic_df[titanic_df.duplicated(subset="Ticket", keep="first")]
duplicate_ticket.head()
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 24            25         0       3      Palsson, Miss. Torborg Danira  female
# 71            72         0       3         Goodwin, Miss. Lillian Amy  female
# 88            89         1       1         Fortune, Miss. Mabel Helen  female
# 117          118         0       2    Turpin, Mr. William John Robert    male
# 119          120         0       3  Andersson, Miss. Ellis Anna Maria  female
#
#       Age  SibSp  Parch   Ticket     Fare        Cabin Embarked
# 24    8.0      3      1   349909   21.075          NaN        S
# 71   16.0      5      2  CA 2144   46.900          NaN        S
# 88   23.0      3      2    19950  263.000  C23 C25 C27        S
# 117  29.0      1      0    11668   21.000          NaN        S
# 119   2.0      4      2   347082   31.275          NaN        S

# %%
titanic_df[titanic_df.Ticket == "349909"]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 24            25         0       3
# 374          375         0       3
# 567          568         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 7                 Palsson, Master. Gosta Leonard    male   2.0      3      1
# 24                 Palsson, Miss. Torborg Danira  female   8.0      3      1
# 374                   Palsson, Miss. Stina Viola  female   3.0      3      1
# 567  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
#
#      Ticket    Fare Cabin Embarked
# 7    349909  21.075   NaN        S
# 24   349909  21.075   NaN        S
# 374  349909  21.075   NaN        S
# 567  349909  21.075   NaN        S

# %%
#duplicate rows
titanic_df[titanic_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#isin, where
titanic_df[titanic_df.Ticket.isin(["349909"])]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 24            25         0       3
# 374          375         0       3
# 567          568         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 7                 Palsson, Master. Gosta Leonard    male   2.0      3      1
# 24                 Palsson, Miss. Torborg Danira  female   8.0      3      1
# 374                   Palsson, Miss. Stina Viola  female   3.0      3      1
# 567  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
#
#      Ticket    Fare Cabin Embarked
# 7    349909  21.075   NaN        S
# 24   349909  21.075   NaN        S
# 374  349909  21.075   NaN        S
# 567  349909  21.075   NaN        S

# %%
titanic_df.Ticket.isin(["349909"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Ticket, Length: 891, dtype: bool

# %%
# where
# mask
titanic_df.Age.where( titanic_df.Age > 0, other =1)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     1.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic_df.Age.mask( titanic_df.Age < 0, other =1)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# filter using index

# %%
titanic_df.loc[:10 , ["Name","Age"]]
# Out:
#                                                  Name   Age
# 0                             Braund, Mr. Owen Harris  22.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                              Heikkinen, Miss. Laina  26.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                            Allen, Mr. William Henry  35.0
# 5                                    Moran, Mr. James   NaN
# 6                             McCarthy, Mr. Timothy J  54.0
# 7                      Palsson, Master. Gosta Leonard   2.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10                    Sandstrom, Miss. Marguerite Rut   4.0

# %%
titanic_df.loc[890, ["Name","Age"]]
# Out:
# Name    Dooley, Mr. Patrick
# Age                    32.0
# Name: 890, dtype: object
