# %%
import numpy as np

a = np.random.randint(10, 50, size =  (5, 2, 3), dtype = "int16")

# %%
a.shape
# Out:
# (5, 2, 3)

# %%
a.ndim
# Out:
# 3

# %%
a.dtype
# Out:
# dtype('int16')

# %%
a.T
# Out:
# array([[[10, 16, 14, 45, 27],
#         [42, 35, 20, 29, 45]],
#
#        [[18, 49, 13, 44, 43],
#         [30, 17, 10, 34, 18]],
#
#        [[31, 36, 29, 48, 36],
#         [31, 40, 15, 22, 34]]], dtype=int16)

# %%
a.size
# Out:
# 30

# %%
a = np.random.randint(10, 50, size =  (5, 4), dtype = "int16")
a
# Out:
# array([[36, 28, 26, 36],
#        [30, 14, 20, 43],
#        [37, 24, 20, 48],
#        [21, 46, 42, 41],
#        [41, 34, 33, 15]], dtype=int16)

# %%
b = a.reshape(2, 5, 2)
b
# Out:
# array([[[36, 28],
#         [26, 36],
#         [30, 14],
#         [20, 43],
#         [37, 24]],
#
#        [[20, 48],
#         [21, 46],
#         [42, 41],
#         [41, 34],
#         [33, 15]]], dtype=int16)

# %%
a.reshape(4, -1)
# Out:
# array([[36, 28, 26, 36, 30],
#        [14, 20, 43, 37, 24],
#        [20, 48, 21, 46, 42],
#        [41, 41, 34, 33, 15]], dtype=int16)

# %%
a.flatten()
# Out:
# array([36, 28, 26, 36, 30, 14, 20, 43, 37, 24, 20, 48, 21, 46, 42, 41, 41,
#        34, 33, 15], dtype=int16)

# %%
a.sum()
# Out:
# np.int64(635)

# %% [markdown]
# 0 -> column wise -> vertical
#
# 1 -> row wise -> horizontal

# %%
a.sum(axis = 0)
# Out:
# array([165, 146, 141, 183])

# %%
a.sum(axis = 1)
# Out:
# array([126, 107, 129, 150, 123])

# %%
a.trace()  #diagonal sum
# Out:
# np.int64(111)

# %%
a.cumsum()
# Out:
# array([ 36,  64,  90, 126, 156, 170, 190, 233, 270, 294, 314, 362, 383,
#        429, 471, 512, 553, 587, 620, 635])

# %%
a.cumsum(axis = 1)
# Out:
# array([[ 36,  64,  90, 126],
#        [ 30,  44,  64, 107],
#        [ 37,  61,  81, 129],
#        [ 21,  67, 109, 150],
#        [ 41,  75, 108, 123]])

# %%
a.prod()
# Out:
# np.int64(-7581503844413079552)

# %%
a.prod(dtype = float)
# Out:
# np.float64(3.334621665652619e+29)

# %%
a
# Out:
# array([[36, 28, 26, 36],
#        [30, 14, 20, 43],
#        [37, 24, 20, 48],
#        [21, 46, 42, 41],
#        [41, 34, 33, 15]], dtype=int16)

# %%
a.argmax(axis=0)
# Out:
# array([4, 3, 3, 2])

# %%
a.argmin(axis=1)
# Out:
# array([2, 1, 2, 0, 3])

# %%
a.clip(min = 20, max = 40)
# Out:
# array([[36, 28, 26, 36],
#        [30, 20, 20, 40],
#        [37, 24, 20, 40],
#        [21, 40, 40, 40],
#        [40, 34, 33, 20]], dtype=int16)

# %%
# concat and joining

# %%
arr1 = np.random.randint(1, 100, size =  (3, 3))
arr2 = np.random.randint(1, 100, size =  (3, 3))

# %%
arr1, arr2
# Out:
# (array([[53, 36,  7],
#         [17, 84, 38],
#         [29, 86, 80]]),
#  array([[44, 12, 20],
#         [32, 10, 58],
#         [19, 98, 13]]))

# %%
np.concatenate((arr1, arr2))
# Out:
# array([[53, 36,  7],
#        [17, 84, 38],
#        [29, 86, 80],
#        [44, 12, 20],
#        [32, 10, 58],
#        [19, 98, 13]])

# %%
np.concatenate((arr1, arr2), axis = 0) # vstack
# Out:
# array([[53, 36,  7],
#        [17, 84, 38],
#        [29, 86, 80],
#        [44, 12, 20],
#        [32, 10, 58],
#        [19, 98, 13]])

# %%
np.vstack((arr1, arr2))
# Out:
# array([[53, 36,  7],
#        [17, 84, 38],
#        [29, 86, 80],
#        [44, 12, 20],
#        [32, 10, 58],
#        [19, 98, 13]])

# %%
np.concatenate((arr1, arr2), axis = 1) # hstack
# Out:
# array([[53, 36,  7, 44, 12, 20],
#        [17, 84, 38, 32, 10, 58],
#        [29, 86, 80, 19, 98, 13]])

# %%
np.hstack((arr1, arr2))
# Out:
# array([[53, 36,  7, 44, 12, 20],
#        [17, 84, 38, 32, 10, 58],
#        [29, 86, 80, 19, 98, 13]])

# %% [markdown]
# accessing an array

# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4, 5])  #1D array

# %%
print(a[3])
# Out:
# 4

# %%
a[2::1]
# Out:
# array([3, 4, 5])

# %%
a[::-1]
# Out:
# array([5, 4, 3, 2, 1])

# %%
#2D array
arr = np.random.randint(0,10, size = (5, 4))
arr
# Out:
# array([[0, 8, 9, 7],
#        [0, 4, 3, 3],
#        [5, 2, 2, 3],
#        [6, 5, 5, 8],
#        [0, 0, 4, 3]])

# %%
arr[2, -1] #arr[2][-1]
# Out:
# np.int64(3)

# %%
arr[-1,-1]
# Out:
# np.int64(3)

# %%
#slicing 2D array

# %%
arr[1:4, 2:]
# Out:
# array([[3, 3],
#        [2, 3],
#        [5, 8]])

# %%
arr[:, -1:]
# Out:
# array([[7],
#        [3],
#        [3],
#        [8],
#        [3]])

# %%
arr[2:4, 1:3]
# Out:
# array([[2, 2],
#        [5, 5]])

# %%
arr[2:4]
# Out:
# array([[5, 2, 2, 3],
#        [6, 5, 5, 8]])

# %%
#3D array

# %%
np.random.seed(99)

arr = np.random.randint(0, 10, size = (3, 4, 3))

# %%
arr
# Out:
# array([[[1, 3, 9],
#         [8, 9, 8],
#         [2, 4, 5],
#         [4, 1, 7]],
#
#        [[3, 7, 1],
#         [1, 0, 6],
#         [4, 7, 2],
#         [0, 8, 8]],
#
#        [[4, 9, 7],
#         [5, 4, 9],
#         [1, 9, 0],
#         [5, 9, 3]]])

# %%
arr[1]
# Out:
# array([[3, 7, 1],
#        [1, 0, 6],
#        [4, 7, 2],
#        [0, 8, 8]])

# %%
arr[1,-1,1] #indexing 3D array
# Out:
# np.int64(8)

# %%
arr[::, 1, -2:] #slicing 3D array
# Out:
# array([[9, 8],
#        [0, 6],
#        [4, 9]])

# %%
dataset = np.random.randint(0, 255, size = (16, 1, 720, 720))

# %%
dataset.shape
# Out:
# (16, 1, 720, 720)

# %%
import matplotlib.pyplot as plt

plt.imshow(dataset[0].reshape(720,720,-1))
# Out:
# Matplotlib is building the font cache; this may take a moment.
