# %% [markdown]
# py decorators

# %%
class Test:

    @staticmethod
    def something():
        print("hey")

# %% [markdown]
# implementation

# %%
def decorator(func):
    
    def wrapper():

        print("before function call")
        print(func().upper())
        print("after function call")

    return wrapper

# %%
@decorator
def greet():
    return "hello"

# %%
greet()
# Out:
# before function call
# HELLO
# after function call
