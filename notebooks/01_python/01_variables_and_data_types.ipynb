# %%
number = 1234

# %%
type(number)
# Out:
# int

# %%
number = -9857625438459272543

# %%
type(number)
# Out:
# int

# %%
print(number)
# Out:
# -9857625438459272543

# %%
num2 = int(569)

# %%
pie = 3.142857

# %%
type(pie)
# Out:
# float

# %%
num2 = float(56.36)
num2
# Out:
# 56.36

# %%
vec = 6 + 3j

# %%
type(vec)
# Out:
# complex

# %%
a = 9
b = 8.6

# %%
c = a + b
print(c)
# Out:
# 17.6

# %%
c = a - b
print(c)
# Out:
# 0.40000000000000036

# %%
c = a * b
print(c)
# Out:
# 77.39999999999999

# %%
c = a / b
print(c)
# Out:
# 1.0465116279069768

# %%
c = 5 % 2
print(c)
# Out:
# 1

# %%
c = 5 // 2
print(c)
# Out:
# 2

# %%
c = 6 ** 2
print(c)
# Out:
# 36
