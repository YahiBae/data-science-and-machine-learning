# %% [markdown]
# random module

# %%
import random

# %% [markdown]
# uniform distribution ufnctions

# %%
random.random()
# Out:
# 0.3302539053245389

# %%
random.uniform(1, 10)
# Out:
# 4.220956831860459

# %%
random.randint(10,20)
# Out:
# 10

# %%
random.randrange(1, 10, 2)
# Out:
# 1

# %%
cards = ['Jack', 'Queen', 'King', 'Ace']

# %%
random.shuffle(cards)

# %%
cards
# Out:
# ['King', 'Ace', 'Queen', 'Jack']

# %%
random.choice(cards)
# Out:
# 'King'

# %%
random.choices(cards, k = 2)
# Out:
# ['Jack', 'King']

# %% [markdown]
# distributions and probability density functions

# %%
random.normalvariate()
# Out:
# 0.08697938525785785

# %%
random.normalvariate(mu=5, sigma=2.2)
# Out:
# 6.844850594971738

# %% [markdown]
# randomness-related functions

# %%
random.seed(456)

# %%
random.random()
# Out:
# 0.7482025358782363

# %%
random.randint(1, 100)
# Out:
# 60
