# %% [markdown]
# encapsulation in py :-
# 1.private
# 2.protected
# 3.public

# %%
class Example:
    def __init__(self):
        self.public = 1
        self._protected = 23
        self.__private = 45

    def public_method(self):
        print("This is a public method.")

    def _protected_method(self):
        print("This is a protected method.")

    def __private_method(self):
        print("This is a private method.")

# %%
obj = Example()

# %%
obj.public
# Out:
# 1

# %%
obj._protected
# Out:
# 23

# %%
obj.public_method()
# Out:
# This is a public method.

# %%
obj._protected_method()
# Out:
# This is a protected method.

# %%
class Subclass(Example):
    def get_public(self):
        print(self.public)

    def get_protected(self):
        print(self._protected)

    def get_private(self):
        print(self.__private)

# %%
sub_obj = Subclass()

# %%
sub_obj.get_public()
# Out:
# 1

# %% [markdown]
# problem solving

# %%
class SmartDevice:
    def __init__(self, device_name):
        self.device_name = device_name
        self._firmware_version = "v1.0"
        self.__system_key = "SECRET_KEY_123"

    def get_device_status(self):
        return f"Device: {self.device_name}, Firmware: {self._firmware_version}"


smart_device = SmartDevice("Smart Speaker")
print(smart_device.get_device_status())
# Out:
# Device: Smart Speaker, Firmware: v1.0
