# %% [markdown]
# py date and time modules

# %%
import datetime

# %%
birth_date = datetime.date(2003, 12, 28)

# %%
today = datetime.date.today()

# %%
age = today - birth_date

# %%
age.days / 365
# Out:
# 22.654794520547945

# %%
datetime.date.fromtimestamp(1672444800)
# Out:
# datetime.date(2022, 12, 31)

# %%
datetime.date.fromisoformat('2023-01-01')
# Out:
# datetime.date(2023, 1, 1)

# %%
dt = datetime.datetime(2025, 1, 1, 12, 29, 55)
dt
# Out:
# datetime.datetime(2025, 1, 1, 12, 29, 55)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 8, 18, 7, 50, 15, 215066)

# %%
datetime.datetime.fromtimestamp(1672444800)
# Out:
# datetime.datetime(2022, 12, 31, 5, 45)

# %%
datetime.datetime.now() - dt
# Out:
# datetime.timedelta(days=593, seconds=69620, microseconds=246602)

# %%
year_5 = datetime.timedelta(days=5*365)

# %%
today + year_5
# Out:
# datetime.date(2031, 8, 17)

# %%
NST = datetime.datetime.now().astimezone(datetime.timezone(datetime.timedelta(hours=9)))

# %%
print(NST)
# Out:
# 2026-08-18 11:05:15.279311+09:00

# %% [markdown]
# time

# %%
import time

# %%
time.time()
# Out:
# 1787018715.333816

# %%
time.ctime()
# Out:
# 'Tue Aug 18 07:50:15 2026'

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=8, tm_mday=18, tm_hour=2, tm_min=5, tm_sec=15, tm_wday=1, tm_yday=230, tm_isdst=0)

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=8, tm_mday=18, tm_hour=7, tm_min=50, tm_sec=15, tm_wday=1, tm_yday=230, tm_isdst=0)

# %%
time.asctime()
# Out:
# 'Tue Aug 18 07:50:15 2026'

# %%
time.strftime("%H hour , %M minute, %S second")
# Out:
# '07 hour , 50 minute, 15 second'

# %%
print("loading...")
time.sleep(5)
print("done loading")
# Out:
# loading...
# done loading

# %%
start = time.time()

print("function started")
time.sleep(5)
print("function ended")

end = time.time()
# Out:
# function started
# function ended

# %%
end - start
# Out:
# 5.005616188049316
