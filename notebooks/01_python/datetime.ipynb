# %% [markdown]
# py date and time modules

# %%
import datetime

# %%
birth_date = datetime.date(2003, 12, 28)

# %%
today = datetime.date.today()

# %%
age = today - birth_date

# %%
age.days / 365
# Out:
# 22.654794520547945

# %%
datetime.date.fromtimestamp(1672444800)
# Out:
# datetime.date(2022, 12, 31)

# %%
datetime.date.fromisoformat('2023-01-01')
# Out:
# datetime.date(2023, 1, 1)

# %%
dt = datetime.datetime(2025, 1, 1, 12, 29, 55)
dt
# Out:
# datetime.datetime(2025, 1, 1, 12, 29, 55)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 8, 18, 7, 39, 24, 539687)

# %%
datetime.datetime.fromtimestamp(1672444800)
# Out:
# datetime.datetime(2022, 12, 31, 5, 45)

# %%
datetime.datetime.now() - dt
# Out:
# datetime.timedelta(days=593, seconds=68969, microseconds=561639)

# %%
year_5 = datetime.timedelta(days=5*365)

# %%
today + year_5
# Out:
# datetime.date(2031, 8, 17)

# %%
NST = datetime.datetime.now().astimezone(datetime.timezone(datetime.timedelta(hours=9)))

# %%
print(NST)
# Out:
# 2026-08-18 10:54:24.594801+09:00

# %% [markdown]
# time

# %%
import time

# %%
time.time()
# Out:
# 1787018064.622483

# %%
time.ctime()
# Out:
# 'Tue Aug 18 07:39:24 2026'

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=8, tm_mday=18, tm_hour=1, tm_min=54, tm_sec=24, tm_wday=1, tm_yday=230, tm_isdst=0)

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=8, tm_mday=18, tm_hour=7, tm_min=39, tm_sec=24, tm_wday=1, tm_yday=230, tm_isdst=0)

# %%
time.asctime()
# Out:
# 'Tue Aug 18 07:39:24 2026'

# %%
time.strftime("%H hour , %M minute, %S second")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 time.strtime("%H hour , %M minute, %S second")
#
# AttributeError: module 'time' has no attribute 'strtime'

# %%
print("loading...")
time.sleep(5)
print("done loading")
# Out:
# loading...
# done loading
