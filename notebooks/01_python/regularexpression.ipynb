# %% [markdown]
# regular expression in py

# %%
import re

# %% [markdown]
# python regexr methods

# %%
string = "ArithmeticError is a built-in exception class in Python that is raised when an error occurs in an arithmetic operation. It is a subclass of the Exception class and is used to indicate that an arithmetic operation has failed due to some reason, such as division by zero or overflow."
print(string)
# Out:
# ArithmeticError is a built-in exception class in Python that is raised when an error occurs in an arithmetic operation. It is a subclass of the Exception class and is used to indicate that an arithmetic operation has failed due to some reason, such as division by zero or overflow.

# %%
pattern = r"in"

match = re.search(pattern, string)

# %%
if match:
    print("match start:", match.start() )
    print("match end:", match.end() )
# Out:
# match start: 27
# match end: 29

# %% [markdown]
# re,findall(pattern,string)

# %%
string = "ArithmeticError is a built-in exception class in Python that is raised when an error occurs in an arithmetic operation. It is a subclass of the Exception class and is used to indicate that an arithmetic operation has failed due to some reason, such as division by zero or overflow."
pattern = r"[A-Z]{2,1}"
